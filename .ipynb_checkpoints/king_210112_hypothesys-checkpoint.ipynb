# %% [markdown]
# # Hypothesys Tests

# %% [markdown]
# 가설을 세우고 접근을 해야할 것 같습니다. 어차피 최종 결과를 내려면 그래야 합니다.

# %% [markdown]
# 일단 대충 세운 가설들은 이렇습니다.
#
# 1. fwver이 error에 영향을 미칠까?
# 2. fwver이 바뀐 user에게 error가 지속된다면?
# 3. model이 error에 영향을 미칠까?
# 4. quality 중에 뭐가 가장 중요할까?
# 5. quality의 임계점은 어디일까?
# 6. 특정 model이나 fw에서 자주 발생하는 err이 있을까?
# 7. 특정 hour에서 발생하는 err이 영향을 미칠까?

# %% [markdown]
# # IMPORT & LOAD DATA

# %%
import load_dtypes as ld
import warnings
warnings.filterwarnings(action='ignore')

import os, sys
import time
import datetime as dt

import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 500)

import matplotlib.pyplot as plt
import seaborn as sns

from tqdm import tqdm

from sklearn.model_selection import train_test_split
from sklearn.metrics import auc, roc_auc_score, roc_curve, precision_recall_curve, recall_score, precision_score

import lightgbm as lgb
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import StratifiedKFold

# %%
#-------------------------------------------------------------------------------------
# validation auc score를 확인하기 위해 정의
def f_pr_auc(probas_pred, y_true):
    labels=y_true.get_label()
    p, r, _ = precision_recall_curve(labels, probas_pred)
    score=auc(r,p) 
    return "pr_auc", score, True
#-------------------------------------------------------------------------------------

# %%
TRAIN_P_PATH = r'C:\Users\Wyatt\wyatt37/Data/systemError/train_problem_data.csv'
TRAIN_Q_PATH = r'C:\Users\Wyatt\wyatt37/Data/systemError/train_quality_data.csv'
TRAIN_E_PATH = r'C:\Users\Wyatt\wyatt37/Data/systemError/train_err_data.csv'
TEST_Q_PATH = r'C:\Users\Wyatt\wyatt37/Data/systemError/test_quality_data.csv'
TEST_E_PATH = r'C:\Users\Wyatt\wyatt37/Data/systemError/test_err_data.csv'
SUBMISSION_PATH = r'C:\Users\Wyatt\wyatt37/Data/systemError/sample_submission.csv'

# %%
# %%time
train_p = ld.load_dtypes(TRAIN_P_PATH)
train_q = ld.load_dtypes(TRAIN_Q_PATH)
train_e = ld.load_dtypes(TRAIN_E_PATH)
test_q = ld.load_dtypes(TEST_Q_PATH)
test_e = ld.load_dtypes(TEST_E_PATH)
submission = pd.read_csv(SUBMISSION_PATH)
# Out:
# C:\Users\Wyatt\wyatt37/Data/systemError/train_problem_data.csv
# C:\Users\Wyatt\wyatt37/Data/systemError/train_quality_data.csv
# C:\Users\Wyatt\wyatt37/Data/systemError/train_err_data.csv
# C:\Users\Wyatt\wyatt37/Data/systemError/test_quality_data.csv

# %%
train_p.shape, train_q.shape, train_e.shape, test_q.shape, test_e.shape, submission.shape

# %%
def preprocessing_problem(df, object_='binary'):
    """
    definition:
    train_problem 테이블을 받아서 target 값으로 변환
    1. {0, 1}의 binary로 변환
    2. {0 ~ n}의 multiclass로 변환
    """
    
    # 10001부터 24999까지의 index를 만들어줍니다.
    user_id_idx = np.array(range(10000, 25000, 1))
    
    # train_new_p라는 새로운 df를 만들고 index는 위에서 만든 user_id_idx 로 지정해줍니다.
    new_p = pd.DataFrame(index = user_id_idx)
    new_p['target'] = 0
    
    if object_ == 'binary':
        new_p.iloc[df.user_id.unique()-10000] = 1
        new_p = new_p.reset_index()
        new_p.rename({'index':'user_id'}, axis=1, inplace=True)
        
    elif object_ == 'multi':
        # multi는 count()로 집계를 해줍니다.
        new_p['target'] = df.groupby('user_id')['time'].count()
        new_p = new_p.fillna(0)
        new_p = new_p.reset_index()
        new_p.rename({'index':'user_id'}, axis=1, inplace=True)
        
    return new_p

# %%
train_b_p = preprocessing_problem(train_p, 'binary')
train_m_p = preprocessing_problem(train_p, 'multi')

# %%
def preprocessing_quality(df):
    """
    definition:
    EDA를 통해 알아낸 정보로 train_q, test_q를 정리해서 내뿜어줍니다.
    1. qaulity_3, quality_4 를 drop 합니다.(단일 value)
    2. qaulity_k 변수들을 정수로 encoding 합니다.
    """
    # 먼저 3, 4번을 drop 합니다.
    df.drop(['quality_3', 'quality_4'], axis=1, inplace=True)
    
    # qual 변수만 할당해주고, 정수로 형변환 해줍니다.
    columns = train_q.columns[train_q.columns.str.contains('quality')]
    # for문을 통해 각 column을 반복 작업해줍니다.
    for col in columns:
        try:
            if df[col].dtype == 'float32': # 기존에 float은 패스
                df[col] = df[col].fillna(-2)
            elif df[col].dtype == 'int8' or df[col].dtype == 'int16': # 기존에 int도 패스
                df[col] = df[col].fillna(-2)
                #print(col)
            else:
                df[col] = df[col].astype('object')
                # nan값이 있으면 float으로 갈 수 없으니 '-2' 으로 채워줍니다.
                df[col] = df[col].fillna('-2')
                df[col] = df[col].apply(lambda x: x.replace(',' , ''))
                df[col] = df[col].astype(np.float32)
        except:
            pass
        
    # fwver 에서 null 값이 꽤 있습니다. missing으로 채우겠습니다.
    df.fwver = df.fwver.astype('object')
    df.fwver = df.fwver.fillna('missing')
    df.fwver = df.fwver.astype('category')
        
    return df

# %%
train_q = preprocessing_quality(train_q)
test_q = preprocessing_quality(test_q)

# %%
def preprocessing_fwver(df):
    """
    definition:
    별건 아니고, e-set에 fwver 변수에서 '10' 이라는 값이 있는데, 이게 errtype이랑 겹쳐요.
    그래서 10을 -> 10.00.0000 으로 바꿔줄 겁니다.
    """
    df.fwver = df.fwver.replace('10', '10.10.1000')
        
    return df

# %%
train_e = preprocessing_fwver(train_e)
test_e = preprocessing_fwver(test_e)

# %%
def make_datetime(df, column_name):
    # df 와 column_name을 받아서 datetime 컬럼을 반환해주는 함수
    
    df['year'] = df[column_name].apply(lambda x: str(x)[:4])
    df['month'] = df[column_name].apply(lambda x: str(x)[4:6])
    df['day'] = df[column_name].apply(lambda x: str(x)[6:8])
    df['hour'] = df[column_name].apply(lambda x: str(x)[8:10])
    df['minute'] = '00' # minute을 넣어주지 않으면 datetime이 완성이 안되니, 00으로 넣어줍니다.
    
    df[column_name] = pd.to_datetime(df.year + df.month + df.day + df.hour + df.minute)
    
    return df

# %%
train_p = make_datetime(train_p, 'time')
train_q = make_datetime(train_q, 'time')
test_q = make_datetime(test_q, 'time')
train_e = make_datetime(train_e, 'time')
test_e = make_datetime(test_e, 'time')

# %%
train_b_p.head()

# %%
train_m_p.head()

# %%
train_p.head()

# %%
train_e

# %%
train_q

# %%
train_e.groupby(['hour', 'errtype'])['errtype'].count().unstack()
# Out:
# errtype      1       2       3        4        5       6       7     8     9   \
# hour
# 00         91.0  1640.0  1025.0  46989.0  40875.0  1750.0  1712.0   5.0   1.0
# 01         48.0  1575.0  1061.0  43735.0  26982.0  1889.0  1711.0   5.0   4.0
# 02       4874.0   926.0  1033.0  49389.0  20453.0  2000.0  1989.0   NaN   1.0
# 03       4814.0   777.0  1204.0  49491.0  15700.0  2307.0  2063.0   NaN   NaN
# 04       5047.0   634.0  1361.0  51680.0  13469.0  1951.0  1917.0   NaN   1.0
# 05       2600.0   499.0  1748.0  54072.0  12153.0  2517.0  2503.0   NaN   2.0
# 06        141.0   385.0  1488.0  55515.0  12162.0  2193.0  2163.0   3.0   3.0
# 07        186.0   582.0  1560.0  64503.0  21078.0  2323.0  2280.0   NaN   1.0
# 08        233.0   897.0  1050.0  61840.0  30404.0  1751.0  1661.0   2.0   2.0
# 09        186.0   598.0  1120.0  58227.0  39128.0  1859.0  1750.0   8.0   1.0
# 10        202.0  1232.0  1190.0  55130.0  42253.0  2085.0  2088.0  13.0   4.0
# ...

# %%
train_ebp = pd.merge(train_e, train_b_p, how='outer', on=['user_id'])
train_emp = pd.merge(train_e, train_m_p, how='outer', on=['user_id'])

# %%
train_qbp = pd.merge(train_q, train_b_p, how='left', on=['user_id'])
train_qmp = pd.merge(train_q, train_m_p, how='left', on=['user_id'])

# %%
train_errtype = train_e.groupby(['user_id', 'errtype'])['errtype'].count().unstack()

# %%
train_model = train_e.groupby(['user_id', 'model_nm'])['model_nm'].count().unstack()

# %%
train_fwver = train_e.groupby(['user_id', 'fwver'])['fwver'].count().unstack()

# %%
temp = train_ebp.groupby(['user_id', 'model_nm'])['target'].max().reset_index().dropna()

plt.figure(figsize=(24, 8))
sns.countplot(data=temp, x='model_nm', hue='target')
plt.show()

# %%
temp = train_ebp.groupby(['user_id', 'fwver'])['target'].max().reset_index().dropna()

plt.figure(figsize=(24, 8))
sns.countplot(data=temp, x='fwver', hue='target')
plt.show()

# %%
temp = train_ebp.groupby(['user_id', 'errtype'])['target'].max().reset_index().dropna()

plt.figure(figsize=(24, 8))
sns.countplot(data=temp, x='errtype', hue='target')
plt.show()

# %%
train_qbp
# Out:
#                   time  user_id       fwver  quality_0  quality_1  quality_2  \
# 0       20201129090000    10000  05.15.2138        0.0          0        0.0
# 1       20201129090000    10000  05.15.2138        0.0          0        0.0
# 2       20201129090000    10000  05.15.2138        0.0          0        0.0
# 3       20201129090000    10000  05.15.2138        0.0          0        0.0
# 4       20201129090000    10000  05.15.2138        0.0          0        0.0
# ...                ...      ...         ...        ...        ...        ...
# 828619  20201124033000    24997  04.22.1778        0.0          0        0.0
# 828620  20201124033000    24997  04.22.1778        0.0          0        0.0
# 828621  20201124033000    24997  04.22.1778        0.0          0        0.0
# 828622  20201124033000    24997  04.22.1778        0.0          0        0.0
# 828623  20201124033000    24997  04.22.1778        0.0          0        0.0
#
# ...

# %%
temp = train_qbp.groupby(['user_id', 'quality_0'])['target'].max().reset_index()

plt.figure(figsize=(24, 8))
sns.scatterplot(data=temp, x='user_id', y='quality_0', hue='target')
plt.show()

# %%
temp = train_qbp.groupby(['user_id', 'quality_1'])['target'].max().reset_index()

plt.figure(figsize=(24, 8))
sns.scatterplot(data=temp[temp.quality_1 < 30], x='user_id', y='quality_1', hue='target')
plt.show()

# %%
temp = train_qbp.groupby(['user_id', 'quality_2'])['target'].max().reset_index()

plt.figure(figsize=(24, 8))
sns.scatterplot(data=temp[temp.quality_2 < 30000], x='user_id', y='quality_2', hue='target')
plt.show()

# %%
temp = train_qbp.groupby(['user_id', 'quality_5'])['target'].max().reset_index()

plt.figure(figsize=(24, 8))
sns.scatterplot(data=temp, x='user_id', y='quality_5', hue='target')
plt.show()

# %%
temp = train_qbp.groupby(['user_id', 'quality_6'])['target'].max().reset_index()

plt.figure(figsize=(24, 8))
sns.scatterplot(data=temp, x='user_id', y='quality_6', hue='target')
plt.show()

# %%
temp = train_qbp.groupby(['user_id', 'quality_7'])['target'].max().reset_index()

plt.figure(figsize=(24, 8))
sns.scatterplot(data=temp, x='user_id', y='quality_7', hue='target')
plt.show()

# %%
temp = train_qbp.groupby(['user_id', 'quality_8'])['target'].max().reset_index()

plt.figure(figsize=(24, 8))
sns.scatterplot(data=temp, x='user_id', y='quality_8', hue='target')
plt.show()

# %%
temp = train_qbp.groupby(['user_id', 'quality_9'])['target'].max().reset_index()

plt.figure(figsize=(24, 8))
sns.scatterplot(data=temp, x='user_id', y='quality_9', hue='target')
plt.show()

# %%
temp = train_qbp.groupby(['user_id', 'quality_10'])['target'].max().reset_index()

plt.figure(figsize=(24, 8))
sns.scatterplot(data=temp, x='user_id', y='quality_10', hue='target')
plt.show()

# %%
temp = train_qbp.groupby(['user_id', 'quality_11'])['target'].max().reset_index()

plt.figure(figsize=(24, 8))
sns.scatterplot(data=temp, x='user_id', y='quality_11', hue='target')
plt.show()

# %%
temp = train_qbp.groupby(['user_id', 'quality_12'])['target'].max().reset_index()

plt.figure(figsize=(24, 8))
sns.scatterplot(data=temp, x='user_id', y='quality_12', hue='target')
plt.show()

# %%
plt.figure(figsize=(24, 8))
sns.countplot(data=train_ebp, x='errtype', hue='target')
plt.show()

# %%
plt.figure(figsize=(24, 8))
sns.countplot(data=train_ebp, x='fwver', hue='target')
plt.show()

# %%
plt.figure(figsize=(24, 8))
sns.countplot(data=train_ebp, x='model_nm', hue='target')
plt.show()

# %%
plt.figure(figsize=(24, 8))
sns.barplot(data=train_ebp, x='errcode', hue='target')
plt.show()

# %%
plt.figure(figsize=(18, 12))
sns.scatterplot(data=train_ebp, x='errtype', y='fwver', hue='target')
plt.show()

# %%
plt.figure(figsize=(18, 12))
sns.scatterplot(data=train_ebp, x='user_id', y='errtype', hue='target')
plt.show()

# %%
plt.figure(figsize=(18, 12))
sns.scatterplot(data=train_ebp, x='user_id', y='model_nm', hue='target')
plt.show()

# %%
plt.figure(figsize=(18, 12))
sns.scatterplot(data=train_ebp, x='user_id', y='errcode', hue='target')
plt.show()
